# %%
# %pip install --upgrade langchain-xai

# %%
import getpass
import os

if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
data = """[
    {
      _id: ObjectId('676ae147e64d8c527efb2298'),
      agency_id: 1146,
      toptier_code: '310',
      abbreviation: 'USAB',
      agency_name: 'Access Board',
      congressional_justification_url: 'https://www.access-board.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 9473159.28,
      obligated_amount: 8713121.61,
      budget_authority_amount: 12172850.89,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 9.938197273324172e-7,
      agency_slug: 'access-board',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb2299'),
      agency_id: 1136,
      toptier_code: '302',
      abbreviation: 'ACUS',
      agency_name: 'Administrative Conference of the U.S.',
      congressional_justification_url: 'https://www.acus.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 3694251.09,
      obligated_amount: 3605664.47,
      budget_authority_amount: 3717646.52,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 3.035172684042226e-7,
      agency_slug: 'administrative-conference-of-the-us',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229a'),
      agency_id: 1144,
      toptier_code: '306',
      abbreviation: 'ACHP',
      agency_name: 'Advisory Council on Historic Preservation',
      congressional_justification_url: 'https://www.achp.gov/sites/default/files/2021-06/ACHP%202022%20Budget%20Justification-final-5-10-21.pdf',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 11307028.28,
      obligated_amount: 11053390.69,
      budget_authority_amount: 13405261.73,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.0000010944366013940625,
      agency_slug: 'advisory-council-on-historic-preservation',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229b'),
      agency_id: 1527,
      toptier_code: '166',
      abbreviation: 'USADF',
      agency_name: 'African Development Foundation',
      congressional_justification_url: 'https://www.usadf.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 36375838.76,
      obligated_amount: 56890299.36,
      budget_authority_amount: 69848042.99,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.0000057025559309241446,
      agency_slug: 'african-development-foundation',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229c'),
      agency_id: 801,
      toptier_code: '072',
      abbreviation: 'USAID',
      agency_name: 'Agency for International Development',
      congressional_justification_url: 'https://www.usaid.gov/cj',
      active_fy: '2024', 
      active_fq: '4',
      outlay_amount: 23659934406.5,
      obligated_amount: 25368710781.91,
      budget_authority_amount: 44198584719.89,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.0036084747781544397,
      agency_slug: 'agency-for-international-development',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229d'),
      agency_id: 805,
      toptier_code: '074',
      abbreviation: 'ABMC',
      agency_name: 'American Battle Monuments Commission',
      congressional_justification_url: 'https://www.abmc.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 102992616.85,
      obligated_amount: 98138664.4,
      budget_authority_amount: 208541237.97,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000017025789449796683,
      agency_slug: 'american-battle-monuments-commission',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229e'),
      agency_id: 1416,
      toptier_code: '309',
      abbreviation: 'ARC',
      agency_name: 'Appalachian Regional Commission',
      congressional_justification_url: 'https://www.arc.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 175625808.89,
      obligated_amount: 382996097.23,
      budget_authority_amount: 815578856.09,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.00006658574591128082,
      agency_slug: 'appalachian-regional-commission',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb229f'),
      agency_id: 879,
      toptier_code: '084',
      abbreviation: 'AFRH',
      agency_name: 'Armed Forces Retirement Home',
      congressional_justification_url: null,
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 102884541.2,
      obligated_amount: 98099078.08,
      budget_authority_amount: 212683197.06,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000017363948578717534,
      agency_slug: 'armed-forces-retirement-home',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a0'),
      agency_id: 1159,
      toptier_code: '313',
      abbreviation: 'GOLDWATER',
      agency_name: 'Barry Goldwater Scholarship and Excellence In Education Foundation',
      congressional_justification_url: 'http://goldwaterscholarship.gov/',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 3458335.52,
      obligated_amount: 3783897.35,
      budget_authority_amount: 43918342.87,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000003585595184757497,
      agency_slug: 'barry-goldwater-scholarship-and-excellence-in-education-foundation',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a1'),
      agency_id: 1426,
      toptier_code: '321',
      abbreviation: 'HERITAGEABROAD',
      agency_name: "Commission for the Preservation of America's Heritage Abroad",
      congressional_justification_url: 'https://www.heritageabroad.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 881267.09,
      obligated_amount: 786460.96,
      budget_authority_amount: 1086787.37,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 8.872783684625541e-8,
      agency_slug: 'commission-for-the-preservation-of-americas-heritage-abroad',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a2'),
      agency_id: 1149,
      toptier_code: '323',
      abbreviation: 'CFA',
      agency_name: 'Commission of Fine Arts',
      congressional_justification_url: 'https://www.cfa.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 8402696.45,
      obligated_amount: 8418836.06,
      budget_authority_amount: 9441601.27,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 7.708341853953987e-7,
      agency_slug: 'commission-of-fine-arts',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a3'),
      agency_id: 1138,
      toptier_code: '326',
      abbreviation: 'USCCR',
      agency_name: 'Commission on Civil Rights',
      congressional_justification_url: 'https://www.usccr.gov/cj/',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 15152499.63,
      obligated_amount: 14154901.59,
      budget_authority_amount: 16427321.4,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.0000013411645490508415,
      agency_slug: 'commission-on-civil-rights',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a4'),
      agency_id: 1139,
      toptier_code: '338',
      abbreviation: 'ABILITYONE',
      agency_name: 'Committee for Purchase from People Who Are Blind or Severely Disabled',
      congressional_justification_url: 'https://www.abilityone.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 14911831.94,
      obligated_amount: 12276869.42,
      budget_authority_amount: 16079164.34,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000001312740200673889,
      agency_slug: 'committee-for-purchase-from-people-who-are-blind-or-severely-disabled',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a5'),
      agency_id: 1129,
      toptier_code: '339',
      abbreviation: 'CFTC',
      agency_name: 'Commodity Futures Trading Commission',
      congressional_justification_url: 'https://www.cftc.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 413586400.85,
      obligated_amount: 429495668.68,
      budget_authority_amount: 706532308.77,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000057682933340633785,
      agency_slug: 'commodity-futures-trading-commission',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a6'),
      agency_id: 1158,
      toptier_code: '581',
      abbreviation: 'CFPB',
      agency_name: 'Consumer Financial Protection Bureau',
      congressional_justification_url: 'https://www.consumerfinance.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 1286635261.12,
      obligated_amount: 1478359909.66,
      budget_authority_amount: 3836811340.31,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.0003132461602060099,
      agency_slug: 'consumer-financial-protection-bureau',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    },
    {
      _id: ObjectId('676ae147e64d8c527efb22a7'),
      agency_id: 694,
      toptier_code: '061',
      abbreviation: 'CPSC',
      agency_name: 'Consumer Product Safety Commission',
      congressional_justification_url: 'https://www.cpsc.gov/cj',
      active_fy: '2024',
      active_fq: '4',
      outlay_amount: 174976213.54,
      obligated_amount: 167067920.21,
      budget_authority_amount: 174342325.49,
      current_total_budget_authority_amount: 12248550270454,
      percentage_of_total_budget_authority: 0.000014233711062977734,
      agency_slug: 'consumer-product-safety-commission',
      fetched_at: ISODate('2024-12-24T16:28:55.878Z')
    }]"""

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# J'adore la programmation.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
                "system",
                """You are a helpful assistant that is good with calculations. now calculate the follwoing mentioned below from the inputted data.We need the totalspending and the total waste, and total deficit from the provided data. What I need is the only three thing as output in dict form
            
                total_spending:$XX.XXT,
                total_waste:$XX.XXT,
                total_deficit:$X,XXX,XXX

                Ensure that none of the values default to zero unless explicitly provided in the data. Use the data to determine these values accurately.
                you are not calcu;ating waste please calculate that also

                output = {{
                "total_spending": $XX.XX,
                "total_waste": $XX.XX,
                "total_deficit": $X,XXX,XXX}}
                """
            ),
            ("human", "{input}"),
    ]
)

chain = prompt | llm
X = chain.invoke(
    {
        "input": data,
    }
)

# %%
X
# Out:
# AIMessage(content='To calculate the total spending, total waste, and total deficit, we need to sum up the respective values from each agency\'s data.\n\n1. **Total Spending**: This is the sum of all `outlay_amount` values.\n2. **Total Waste**: This is the sum of the differences between `obligated_amount` and `outlay_amount` for each agency where `obligated_amount` is greater than `outlay_amount`.\n3. **Total Deficit**: This is the sum of the differences between `budget_authority_amount` and `outlay_amount` for each agency.\n\nLet\'s calculate these:\n\n```python\ndata = [\n    {\n        "outlay_amount": 9473159.28,\n        "obligated_amount": 8713121.61,\n        "budget_authority_amount": 12172850.89\n    },\n    {\n        "outlay_amount": 3694251.09,\n        "obligated_amount": 3605664.47,\n        "budget_authority_amount": 3717646.52\n    },\n    {\n        "outlay_amount": 11307028.28,\n        "obligated_amount": 11053390.69,\n        "budget_authority_amount": 13405261.73\
# ...

# %%
import re

# Extract numerical results from the response content
content = X.content  # Assuming `X` is your chain response object

# Regex patterns to extract the three values
total_spending_match = re.search(r'"total_spending":\s*"\$(.*?)T"', content)
total_waste_match = re.search(r'"total_waste":\s*"\$(.*?)T"', content)
total_deficit_match = re.search(r'"total_deficit":\s*"\$(.*?)"', content)

# Extract values if matches are found
total_spending = total_spending_match.group(1) if total_spending_match else None
total_waste = total_waste_match.group(1) if total_waste_match else None
total_deficit = total_deficit_match.group(1) if total_deficit_match else None

# Create a dictionary for the results
result = {
    "total_spending": f"${total_spending}T" if total_spending else "Not Found",
    "total_waste": f"${total_waste}T" if total_waste else "Not Found",
    "total_deficit": f"${total_deficit}" if total_deficit else "Not Found",
}

print(result)
# Out:
# {'total_spending': '$25.73T', 'total_waste': '$0.92T', 'total_deficit': '$54,091,091,000'}
